# %% [markdown]
# # **SHETH L.U.J. & SIR M.V. COLLEGE**

# %% [markdown]
# **Shreeraj Desai | T075**
# ### Practical No. 2
# **Aim**: Data Frames and Basic Data Pre-processing
#
# *   Read data from CSV and JSON files into a data frame.
# *   Perform basic data pre-processing tasks such as handling missing values and outliers.
# *   Manipulate and transform data using functions like filtering, sorting, and grouping.

# %% [markdown]
# # 2.1 Loading a Sample Dataset

# %%
#load scikit-learn's datasets
from sklearn import datasets
# load digits dataset
digits = datasets.load_iris()
#create features matrix
features = digits.data
#create target vector
target = digits.target
#view first observation
features [0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %% [markdown]
# # 2.2 Creating a Simulated Dataset

# %%
# Load library
from sklearn.datasets import make_regression

# Generate features matrix, target vector, and the true coefficients
features, target, coefficients = make_regression(n_samples=100,
                                                 n_features=3,
                                                 n_informative=3,
                                                 n_targets=1,
                                                 noise=0.0,
                                                 coef=True,
                                                 random_state=1)

# View feature matrix and target vector
print("Feature Matrix \n {}".format(features[:3]))
print("Target Vector \n {}".format(target[:3]))
# Out:
# Feature Matrix
#  [[ 1.29322588 -0.61736206 -0.11044703]
#  [-2.793085    0.36633201  1.93752881]
#  [ 0.80186103 -0.18656977  0.0465673 ]]
# Target Vector
#  [-10.37865986  25.5124503   19.67705609]

# %%
# Load library
from sklearn.datasets import make_classification

# Generate features matrix and target vector
features, target = make_classification(n_samples=100,
                                       n_features=3,
                                       n_informative=3,
                                       n_redundant=0,
                                       n_classes=2,
                                       weights=[0.25, 0.75],
                                       random_state=1)

# View feature matrix and target vector
print("Feature matrix\n {}".format(features[:3]))
print("Target vector\n {}".format(target[:3]))
# Out:
# Feature matrix
#  [[ 1.06354768 -1.42632219  1.02163151]
#  [ 0.23156977  1.49535261  0.33251578]
#  [ 0.15972951  0.83533515 -0.40869554]]
# Target vector
#  [1 0 0]

# %%
# Load library
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate feature_matrix and target vector
features, target = make_blobs(n_samples=100,
                              n_features=2,
                              centers=3,
                              cluster_std=0.5,
                              shuffle=True,
                              random_state=1)

# View feature matrix and target vector
print("Feature Matrix\n {}".format(features[:3]))
print("Target Vector\n {}".format(target[:3]))

# View scatterplot
plt.scatter(features[:, 0], features[:, 1], c=target)
plt.show()
# Out:
# Feature Matrix
#  [[ -1.22685609   3.25572052]
#  [ -9.57463218  -4.38310652]
#  [-10.71976941  -4.20558148]]
# Target Vector
#  [0 1 1]

# %% [markdown]
# # 2.3 Loading a CSV File

# %%
import pandas as pd

# Load from a local CSV file
df = pd.read_csv('mushrooms.csv')

# Inspect the first few rows
print(df.head())

# View dataset information (columns, data types)
print(df.info())
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# # 2.4 Loading an Excel File

# %%
# Load library
import pandas as pd

# Load local Excel file
# Make sure 'mushrooms.xls' is in the same directory as your script,
# or provide the full file path.
df = pd.read_excel("avocado.xlsx")

# View the first two rows
print(df.head(2))
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74  54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28  44638.81
#
#     4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0  48.16     8696.87     8603.62       93.25          0.0  conventional  2015
# 1  58.33     9505.56     9408.07       97.49          0.0  conventional  2015
#
#    region
# 0  Albany
# 1  Albany

# %% [markdown]
# # 2.5 Loading a JSON File

# %%
# Import the pandas library
import pandas as pd

# Load the local JSON file into a DataFrame
# Replace 'mushrooms.json' with the actual path to your file if it's in a different directory
df = pd.read_json('mushrooms.json')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# # 2.6 Querying a SQL Database

# %%
# Load libraries
import pandas as pd
from sqlalchemy import create_engine

# Create a connection to the local SQLite database file
# The format is 'sqlite:///your_database_name.db'
db_connection = create_engine('sqlite:///mushrooms.db')

df = pd.read_sql_query('SELECT * FROM mytable', db_connection)

# View the first few rows of the loaded data
print(df.head())
# Out:
# Empty DataFrame
# Columns: [class, capshape, capsurface, capcolor, bruises, odor, gillattachment, gillspacing, gillsize, gillcolor, stalkshape, stalkroot, stalksurfaceabovering, stalksurfacebelowring, stalkcolorabovering, stalkcolorbelowring, veiltype, veilcolor, ringnumber, ringtype, sporeprintcolor, population, habitat]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### Creating a DataFrame

# %% [markdown]
# # Data Wrangling with Mushrooms Dataset

# %%
import pandas as pd

df = pd.read_json('Datasets/mushrooms.json')

print(df.head(2))

print(df.tail(2))

print("Dimensions: {}".format(df.shape))

print(df.describe())
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
#
# [2 rows x 23 columns]
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# ...

# %% [markdown]
# ### Navigating DataFrame

# %%
print(df.iloc[0])
print(df.iloc[1:4])
print(df.iloc[:4])
# Out:
# class                       p
# cap-shape                   x
# cap-surface                 s
# cap-color                   n
# bruises                     t
# odor                        p
# gill-attachment             f
# gill-spacing                c
# gill-size                   n
# gill-color                  k
# stalk-shape                 e
# stalk-root                  e
# stalk-surface-above-ring    s
# stalk-surface-below-ring    s
# stalk-color-above-ring      w
# stalk-color-below-ring      w
# veil-type                   p
# veil-color                  w
# ring-number                 o
# ring-type                   p
# spore-print-color           k
# population                  s
# habitat                     u
# Name: 0, dtype: object
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# ...

# %% [markdown]
# ### Selecting Rows Based on Conditionals

# %%
df[df['class'] == 'p'].head(2)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 3     p         x           y         w       t    p               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 3            c         n          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 3                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 3           o         p                 k          s       u
#
# [2 rows x 23 columns]

# %%
df[(df['class'] == 'p') & (df['cap-shape'] == 'x')]
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 3        p         x           y         w       t    p               f
# 8        p         x           y         w       t    p               f
# 13       p         x           y         w       t    p               f
# 17       p         x           s         n       t    p               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8005     p         x           y         e       f    s               f
# 8032     p         x           s         n       f    f               f
# 8087     p         x           s         e       f    f               f
# 8093     p         x           s         n       f    y               f
# 8095     p         x           y         c       f    m               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# ### Replacing Values

# %%
df['class'].replace('p', 'poisonous').head(2)
# Out:
# 0    poisonous
# 1            e
# Name: class, dtype: object

# %%
df['class'].replace(['p', 'e'], ['poisonous', 'edible']).head(5)
# Out:
# 0    poisonous
# 1       edible
# 2       edible
# 3    poisonous
# 4       edible
# Name: class, dtype: object

# %% [markdown]
# ### Renaming Columns

# %%
df.rename(columns={'class': 'edibility'}).head(2)
# Out:
#   edibility cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0         p         x           s         n       t    p               f
# 1         e         x           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
#
# [2 rows x 23 columns]

# %%
df.rename(columns={'class': 'edibility', 'cap-shape': 'cap_shape'}).head(2)
# Out:
#   edibility cap_shape cap-surface cap-color bruises odor gill-attachment  \
# 0         p         x           s         n       t    p               f
# 1         e         x           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Finding Unique Values

# %%
print(df['habitat'].unique())
print(df['habitat'].value_counts())
# Out:
# ['u' 'g' 'm' 'd' 'p' 'w' 'l']
# habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: count, dtype: int64

# %% [markdown]
# ### Handling Missing Values

# %%
import numpy as np
df_nan = df.replace('?', np.nan)
df_nan[df_nan['stalk-root'].isnull()].head(2)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3984     e         x           y         b       t    n               f
# 4023     p         x           y         e       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 3984            c         b          e  ...                        s
# 4023            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 3984                      e                      w         p          w
# 4023                      w                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 3984           t         e                 w          c       w
# 4023           o         e                 w          v       p
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Deleting a Column

# %%
df.drop('veil-type', axis=1).head(2)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# 1                        s                      w                      w
#
#   veil-color ring-number ring-type spore-print-color population habitat
# 0          w           o         p                 k          s       u
# 1          w           o         p                 n          n       g
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Deleting a Row

# %%
df[df['class'] != 'p'].head(2)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
#
# [2 rows x 23 columns]

# %%
df[df.index != 0].head(2)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Iterating Over a Column

# %%
for habitat in df['habitat'][0:2]:
    print(habitat.upper())
# Out:
# U
# G

# %%
[habitat.upper() for habitat in df['habitat'][0:2]]
# Out:
# ['U', 'G']

# %% [markdown]
# ### Applying a Function Over All Elements in a Column

# %%
def cap_initial(x):
    return x[0]
df['cap-shape'].apply(cap_initial)[0:2]
# Out:
# 0    x
# 1    x
# Name: cap-shape, dtype: object

# %% [markdown]
# ### Applying a Function to Groups

# %%
df.groupby('class').apply(lambda x: x.count())
# Out:
# C:\Users\Shreeraj_N_Desai\AppData\Local\Temp\ipykernel_8264\1428733157.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('class').apply(lambda x: x.count())
#        class  cap-shape  cap-surface  cap-color  bruises  odor  \
# class
# e       4208       4208         4208       4208     4208  4208
# p       3916       3916         3916       3916     3916  3916
#
#        gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# class                                                        ...
# e                 4208          4208       4208        4208  ...
# p                 3916          3916       3916        3916  ...
#
# ...

# %% [markdown]
# ### Concatenating DataFrames

# %%
df_part1 = df.iloc[0:5, :5]
df_part2 = df.iloc[5:10, :5]
pd.concat([df_part1, df_part2])
# Out:
#   class cap-shape cap-surface cap-color bruises
# 0     p         x           s         n       t
# 1     e         x           s         y       t
# 2     e         b           s         w       t
# 3     p         x           y         w       t
# 4     e         x           s         g       f
# 5     e         x           y         y       t
# 6     e         b           s         w       t
# 7     e         b           y         w       t
# 8     p         x           y         w       t
# 9     e         b           s         y       t
